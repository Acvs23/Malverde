# %%
import pandas as pd

# %%
Dataset = pd.read_csv(
    "UK_Sanctions_Reduced.csv",
)
print(Dataset.head())

print(Dataset.shape)
print(Dataset.columns.tolist())
# Out:
#   Unique ID                                        Name Date of Birth  \
# 0   AFG0001  HAJI KHAIRULLAH HAJI SATTAR MONEY EXCHANGE       Unknown
# 1   AFG0001                            Haji Alim Hawala       Unknown
# 2   AFG0001                           Haji Hakim Hawala       Unknown
# 3   AFG0001              Haji Khair Ullah Money Service       Unknown
# 4   AFG0001              Haji Khairullah Money Exchange       Unknown
#
#     Gender     Name Type Designation Source Designation Type Last Updated  \
# 0  Unknown  Primary Name                 UN           Entity   16/04/2026
# 1  Unknown         Alias                 UN           Entity   16/04/2026
# 2  Unknown         Alias                 UN           Entity   16/04/2026
# 3  Unknown         Alias                 UN           Entity   16/04/2026
# 4  Unknown         Alias                 UN           Entity   16/04/2026
#
#                            Address Country Birth Country Nationalities  \
# ...

# %%
Dataset.sample(n=20, random_state=42)
# Out:
#       Unique ID                                 Name Date of Birth   Gender  \
# 10043   RUS0229     Alexander Victorovych Janukovych    10/07/1973     Male
# 6679    GHR0051    Viktor Aliaksandravich LUKASHENKO    28/11/1975     Male
# 7585    INU0112          National University of Iran       Unknown  Unknown
# 8846    IRN0232              Mohammad-Hossein Dadras       Unknown     Male
# 7640    INU0127                                  TEM       Unknown  Unknown
# 14740   SOM0012                     Abubaker Shariff          1967  Unknown
# 15391   SYR0065              Abdallah Khalil Hussain          1959     Male
# 13095   RUS2428              TKT-1997 RAZVOJ LIMITED       Unknown  Unknown
# 2998    AQD0292                          Abu Ubaydah    16/09/1973  Unknown
# 6698    GHR0053    Khazalbek Bakhtibekavich Atabekau       Unknown     Male
# 14447   RUS3417            LLC PALFINGER SANI CRANES       Unknown  Unknown
# ...

# %%
#Test - Filtering by Unique ID (Exact)
Dataset[Dataset["Unique ID"] == "AFG0001"]
# Out:
#   Unique ID                                               Name Date of Birth  \
# 0   AFG0001         HAJI KHAIRULLAH HAJI SATTAR MONEY EXCHANGE       Unknown
# 1   AFG0001                                   Haji Alim Hawala       Unknown
# 2   AFG0001                                  Haji Hakim Hawala       Unknown
# 3   AFG0001                     Haji Khair Ullah Money Service       Unknown
# 4   AFG0001                     Haji Khairullah Money Exchange       Unknown
# 5   AFG0001       Haji Khairullah and Abdul Sattar and Company       Unknown
# 6   AFG0001                 Haji Khairullah-Haji Sattar Sarafi       Unknown
# 7   AFG0001                                  Haji Salam Hawala       Unknown
# 8   AFG0001  Sarafi-yi Haji Khairullah Haji Satar Haji Esma...       Unknown
#
#     Gender     Name Type Designation Source Designation Type Last Updated  \
# 0  Unknown  Primary Name                 UN           Entity   16/04/2026
# ...

# %%
#Test - Filtering by Date of Birth (Contains)
Dataset[Dataset["Date of Birth"].str.contains("03/1969", na=False)]
# Out:
#       Unique ID                           Name Date of Birth   Gender  \
# 11007   RUS1005       Grigory Petrovich LEDKOV    26/03/1969  Unknown
# 11797   RUS1538  Vladislav Garievich KUZNETSOV    18/03/1969     Male
# 11980   RUS1668   Denis Valentinovich MANTUROV    23/03/1969     Male
# 17018   VEN0030        Juan Jose Mendoza Jover    11/03/1969     Male
#
#           Name Type Designation Source Designation Type Last Updated  \
# 11007  Primary Name                 UK       Individual   09/04/2025
# 11797  Primary Name                 UK       Individual   09/04/2025
# 11980  Primary Name                 UK       Individual   09/04/2025
# 17018  Primary name                 UK       Individual   09/04/2025
#
#       Address Country Birth Country Nationalities National Identifier number  \
# 11007          Russia        Russia       Unknown                    Unknown
# 11797         Unknown        Russia        Russia                    Unknown
# ...

# %%
#Test - Filtering by Nationalities (Contains)
Dataset[Dataset["Nationalities"].str.contains("Canada", na=False)]
# Out:
#       Unique ID                 Name Date of Birth Gender     Name Type  \
# 4792    CTI0007              El-Hajj    22/03/1988   Male         Alias
# 4793    CTI0007       El-Hajj Hassan    22/03/1988   Male         Alias
# 4794    CTI0007       Hassan El-Hajj    22/03/1988   Male  Primary name
# 11521   RUS1338     Eugene Tenenbaum       09/1964   Male  Primary Name
# 14116   RUS3165  Murtaza Ali LAKHANI    08/03/1962   Male  Primary Name
#
#       Designation Source Designation Type Last Updated Address Country  \
# 4792                  UK       Individual   09/04/2025         Lebanon
# 4793                  UK       Individual   09/04/2025         Lebanon
# 4794                  UK       Individual   09/04/2025         Lebanon
# 11521                 UK       Individual   28/07/2023         Unknown
# 14116                 UK       Individual   18/12/2025  United Kingdom
#
#       Birth Country     Nationalities National Identifier number  \
# ...
